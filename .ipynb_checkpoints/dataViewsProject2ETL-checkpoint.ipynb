# %%
# dependencies
import pandas as pd
import csv

# %%
# File to Load 
csv_path = "aggregated_data.csv"

# Read file
aggregated_data = pd.read_csv(csv_path)

# %%
aggregated_data.head()
# Out:
#      zip state  num_mcd  num_sbx  num_wf     rets      dep  ret_tot_inc  \
# 0  10001    NY        5       15       5  14520.0   3290.0      14520.0
# 1  10002    NY        2        1       2  42180.0  17490.0      42180.0
# 2  10003    NY        2       10       2  28660.0   4490.0      28660.0
# 3  10004    NY        0        6       0   2480.0   1030.0       2480.0
# 4  10005    NY        0        6       0   5940.0   1220.0       5940.0
#
#      tot_inc  ret_wages      wages  rets_bus_inc   bus_inc  ret_cap_gain  \
# 0  2323084.0    12080.0  1618969.0        2980.0   82477.0        4470.0
# 1  2313723.0    35240.0  1802797.0        7690.0  113416.0        6110.0
# 2  6720746.0    23400.0  3965359.0        6710.0  261633.0       12880.0
# 3   830828.0     2140.0   550998.0         510.0   23702.0        1050.0
# 4  3171561.0     5200.0   948413.0         930.0   41932.0        2340.0
#
#    cap_gain  rets_unemp   unemp  rets_stu_loan_deduct  stu_loan_deduct
# ...

# %%
print(aggregated_data.head())
# Out:
#      zip state  num_mcd  num_sbx  num_wf     rets      dep  ret_tot_inc  \
# 0  10001    NY        5       15       5  14520.0   3290.0      14520.0
# 1  10002    NY        2        1       2  42180.0  17490.0      42180.0
# 2  10003    NY        2       10       2  28660.0   4490.0      28660.0
# 3  10004    NY        0        6       0   2480.0   1030.0       2480.0
# 4  10005    NY        0        6       0   5940.0   1220.0       5940.0
#
#      tot_inc  ret_wages      wages  rets_bus_inc   bus_inc  ret_cap_gain  \
# 0  2323084.0    12080.0  1618969.0        2980.0   82477.0        4470.0
# 1  2313723.0    35240.0  1802797.0        7690.0  113416.0        6110.0
# 2  6720746.0    23400.0  3965359.0        6710.0  261633.0       12880.0
# 3   830828.0     2140.0   550998.0         510.0   23702.0        1050.0
# 4  3171561.0     5200.0   948413.0         930.0   41932.0        2340.0
#
#    cap_gain  rets_unemp   unemp  rets_stu_loan_deduct  stu_loan_deduct
# ...

# %%
# File to Load 
csv_path = "McDlocsAllClean.csv"

# Read file
McDlocsAllClean = pd.read_csv(csv_path)

# %%
McDlocsAllClean.head()
# Out:
#    store_number  mcdzips
# 0           100    33801
# 1           101    60025
# 2           103    21401
# 3           104    20745
# 4           108    61832

# %%
print(McDlocsAllClean.head())
# Out:
#    store_number  mcdzips
# 0           100    33801
# 1           101    60025
# 2           103    21401
# 3           104    20745
# 4           108    61832

# %%
# File to Load 
csv_path = "IRS2016_abridged.csv"

# Read file
IRS2016_abridged = pd.read_csv(csv_path)

# %%
IRS2016_abridged.head()
# Out:
#    zipcode STATE  agi_stub      N1  NUMDEP  N02650    A02650  N00200  \
# 0        0    AL         1  815440  491310  815440  10787121  651680
# 1        0    AL         2  495830  360480  495830  18020908  427840
# 2        0    AL         3  263390  182880  263390  16351320  225610
# 3        0    AL         4  167190  130160  167190  14646693  144290
# 4        0    AL         5  217440  195990  217440  29696755  193550
#
#      A00200  N00900  A00900  N01000  A01000  N02300  A02300  N03210  A03210
# 0   8466376  144430  765184   34770   20594   22770   65220   17110   14893
# 1  14690098   65350  258861   31040   50118   15170   45546   41490   43047
# 2  12476022   41390  259064   31240   85650    7460   24614   29110   31929
# 3  10900188   28910  240845   27320  103892    3850   13372   20610   23854
# 4  21806247   43180  684832   59160  506542    2280    8380   22870   24745

# %%
print(IRS2016_abridged.head())
# Out:
#    zipcode STATE  agi_stub      N1  NUMDEP  N02650    A02650  N00200  \
# 0        0    AL         1  815440  491310  815440  10787121  651680
# 1        0    AL         2  495830  360480  495830  18020908  427840
# 2        0    AL         3  263390  182880  263390  16351320  225610
# 3        0    AL         4  167190  130160  167190  14646693  144290
# 4        0    AL         5  217440  195990  217440  29696755  193550
#
#      A00200  N00900  A00900  N01000  A01000  N02300  A02300  N03210  A03210
# 0   8466376  144430  765184   34770   20594   22770   65220   17110   14893
# 1  14690098   65350  258861   31040   50118   15170   45546   41490   43047
# 2  12476022   41390  259064   31240   85650    7460   24614   29110   31929
# 3  10900188   28910  240845   27320  103892    3850   13372   20610   23854
# 4  21806247   43180  684832   59160  506542    2280    8380   22870   24745

# %%
# File to Load 
csv_path = "WFlocs.csv"

# Read file
WFlocs = pd.read_csv(csv_path)

# %%
WFlocs.head()
# Out:
#                        Wf_address  Wf_zip
# 0       327 Russell St Hadley, MA    1035
# 1   255 Amherst Street Nashua, NH    3063
# 2     40 Railroad St. Andover, MA    1810
# 3        170 Great Rd Bedford, MA    1730
# 4  4004 Bellaire Blvd Houston, TX   77025

# %%
print(WFlocs.head())
# Out:
#                        Wf_address  Wf_zip
# 0       327 Russell St Hadley, MA    1035
# 1   255 Amherst Street Nashua, NH    3063
# 2     40 Railroad St. Andover, MA    1810
# 3        170 Great Rd Bedford, MA    1730
# 4  4004 Bellaire Blvd Houston, TX   77025

# %%
# File to Load 
csv_path = "zip_codes_cleaned.csv"

# Read file
zip_codes_cleaned = pd.read_csv(csv_path)

# %%
zip_codes_cleaned.head()
# Out:
#    zip      type  decommissioned primary_city state               county  \
# 0  501    UNIQUE               0   Holtsville    NY       Suffolk County
# 1  544    UNIQUE               0   Holtsville    NY       Suffolk County
# 2  601  STANDARD               0     Adjuntas    PR   Adjuntas Municipio
# 3  602  STANDARD               0       Aguada    PR     Aguada Municipio
# 4  603  STANDARD               0    Aguadilla    PR  Aguadilla Municipio
#
#               timezone area_codes world_region country  latitude  longitude  \
# 0     America/New_York        631          NaN      US     40.81     -73.04
# 1     America/New_York        631          NaN      US     40.81     -73.04
# 2  America/Puerto_Rico    787,939          NaN      US     18.16     -66.72
# 3  America/Puerto_Rico    787,939          NaN      US     18.38     -67.18
# 4  America/Puerto_Rico        787          NaN      US     18.43     -67.15
#
#    irs_estimated_population_2015
# 0                            562
# ...

# %%
print(zip_codes_cleaned.head())
# Out:
#    zip      type  decommissioned primary_city state               county  \
# 0  501    UNIQUE               0   Holtsville    NY       Suffolk County
# 1  544    UNIQUE               0   Holtsville    NY       Suffolk County
# 2  601  STANDARD               0     Adjuntas    PR   Adjuntas Municipio
# 3  602  STANDARD               0       Aguada    PR     Aguada Municipio
# 4  603  STANDARD               0    Aguadilla    PR  Aguadilla Municipio
#
#               timezone area_codes world_region country  latitude  longitude  \
# 0     America/New_York        631          NaN      US     40.81     -73.04
# 1     America/New_York        631          NaN      US     40.81     -73.04
# 2  America/Puerto_Rico    787,939          NaN      US     18.16     -66.72
# 3  America/Puerto_Rico    787,939          NaN      US     18.38     -67.18
# 4  America/Puerto_Rico        787          NaN      US     18.43     -67.15
#
#    irs_estimated_population_2015
# 0                            562
# ...

# %%
# File to Load 
csv_path = "SbxLocs(Feb2017).csv"

# Read file
starbucksdata = pd.read_csv(csv_path)

# %%
starbucksdata.head()
# Out:
#        Brand  Store_Number        Store_Name Ownership_Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street_Address              City State_Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone_Number                 Timezone  Longitude  Latitude  \
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
print(starbucksdata.head())
# Out:
#        Brand  Store_Number        Store_Name Ownership_Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street_Address              City State_Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone_Number                 Timezone  Longitude  Latitude  \
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...
